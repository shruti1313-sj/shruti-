# %%
# find the length of given string(given by user) without using len() fun

# %%
a=input("enter any string" )
print(a)
count=0
for i in a:
  count += 1
print(" length of string is", count)

# %%
# extract userid from given mail i'd
# eg if the mail is abcd67@gmail.com
# then user name should be "abcd67"

# %%
# ans
id=input("enter your mail_id  ")
print(id)
a=id.index("@")
print(id[0:a])

# %%
# count the frequency of perticular char in provided string e\
# eg "hello how are you" is the string,
# the frequency of "h" in this string is 2
# without using count ()

# %%
# ans

str=input(" enter a string  ")
term=input("what would you like to search")

counter=0
for i in str:
  if i==term:
    counter += 1
print("frequency of your char is " ,counter)

# %%
# write a program which can remove a particular char from string

# %%
#ans


s= input("enter your sting  ")
term=input("what you want to remove ")

result=""

for i in s:
  if i!= term:
    result=result +i
print(result)
